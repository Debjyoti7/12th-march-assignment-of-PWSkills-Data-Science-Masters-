# %% [markdown]
# # Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

# %%
import scipy.stats as stats

data = [50] * 100 # create a sample with 100 observations of 50
mean = sum(data) / len(data) # calculate the mean
std_dev = 5 # given standard deviation
n = len(data) # sample size
alpha = 0.05 # 95% confidence level

# calculate the standard error
std_error = std_dev / (n ** 0.5)

# calculate the margin of error
margin_error = stats.t.ppf(1 - alpha/2, n-1) * std_error

# calculate the confidence interval
lower_bound = mean - margin_error
upper_bound = mean + margin_error

# print the results
print(f"95% Confidence interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# 95% Confidence interval: (49.01, 50.99)

# %% [markdown]
# # Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% brown. Use Python to perform the test with a significance level of 0.05.

# %%
import numpy as np
from scipy.stats import chisquare

# observed frequencies from a sample
observed_frequencies = np.array([18, 22, 19, 11, 10, 20])

# expected frequencies based on the given distribution
expected_frequencies = np.array([0.2, 0.2, 0.2, 0.1, 0.1, 0.2]) * np.sum(observed_frequencies)

# perform the chi-square test
chi_sq_stat, p_value = chisquare(observed_frequencies, f_exp=expected_frequencies)

# print the results
print(f"Chi-square statistic: {chi_sq_stat:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("Reject null hypothesis: observed frequencies differ significantly from expected frequencies.")
else:
    print("Fail to reject null hypothesis: observed frequencies do not differ significantly from expected frequencies.")

# %% [markdown]
# # Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following data. Interpret the results of the test.

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

observed = np.array([[20,10,15],[15,25,20]])
chi2, pval, dof, expected = chi2_contingency(observed)

print("Chi-square statistic:", chi2)
print("p-value:", pval)
# Out:
# Chi-square statistic: 5.833333333333334
# p-value: 0.05411376622282158

# %% [markdown]
# ## Interpretation: The p-value obtained is grater than the significance level of 0.05, which means we fail to reject the null hypothesis that there is an association between the rows and columns of the contingency table.

# %% [markdown]
# # Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.

# %%
import statsmodels.api as sm

n = 500  # sample size
p = 60/n  # sample proportion
z = 1.96  # z-value for 95% confidence interval

# calculate standard error and margin of error
se = np.sqrt(p * (1 - p) / n)
me = z * se

# calculate lower and upper bounds of the confidence interval
lcb = p - me
ucb = p + me

print("95% Confidence Interval: ({:.4f}, {:.4f})".format(lcb, ucb))
# Out:
# 95% Confidence Interval: (0.0915, 0.1485)

# %% [markdown]
# # Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats

sample_mean = 75
sample_std = 12
n = 100  # assuming a sample size of 100

# calculate the standard error
standard_error = sample_std / (n ** 0.5)

# calculate the margin of error
margin_of_error = stats.t.ppf(0.95, n-1) * standard_error

# calculate the lower and upper bounds of the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("90% Confidence Interval: ({:.2f}, {:.2f})".format(lower_bound, upper_bound))
# Out:
# 90% Confidence Interval: (73.01, 76.99)

# %% [markdown]
# # Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

df = 10
x = np.linspace(0, 30, 200)
y = chi2.pdf(x, df)

fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(x, y, 'b-', lw=2, label='chi-square pdf')
ax.fill_between(x[x >= 15], y[x >= 15], 0, alpha=0.5, color='b', label='Area for x > 15')

ax.set_xlabel('x')
ax.set_ylabel('Probability density')
ax.set_title('Chi-square Distribution with df = 10')
ax.legend()

plt.show()

# %% [markdown]
# # Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who prefer Coke.

# %%
## To calculate the 99% confidence interval for the true proportion of people in the population who prefer Coke, we can use the following formula:

## CI = p ± z*(sqrt((p*(1-p))/n))

## where:

## CI is the confidence interval
## p is the proportion of people in the sample who prefer Coke
## z is the critical value from the standard normal distribution for the given confidence level (in this case, 99%)
## n is the sample size
## First, we need to calculate p:

## p = 520/1000 = 0.52

## Next, we need to find the critical value of z for a 99% confidence level. We can use the norm.ppf() function from the scipy.stats module to find this value:

from scipy.stats import norm

z = norm.ppf(0.995)
print(z)
# Out:
# 2.5758293035489004

# %% [markdown]
# ## So, the critical value of z for a 99% confidence level is 2.576 (rounded to three decimal places).
#
# ## Now we can plug in the values into the formula to get the confidence interval:

# %%
import math

n = 1000

lower = p - z*(math.sqrt((p*(1-p))/n))
upper = p + z*(math.sqrt((p*(1-p))/n))

print("95% Confidence Interval: ({:.4f}, {:.4f})".format(lower, upper))
# Out:
# 95% Confidence Interval: (0.0935, 0.1465)

# %% [markdown]
# # Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the expected frequencies of a fair coin. Use a significance level of 0.05.

# %% [markdown]
# ## To conduct the chi-square goodness of fit test, we need to follow the following steps:
#
# ## Step 1: State the null hypothesis and alternative hypothesis
#
# ## Null Hypothesis: The coin is fair, and the observed frequencies match the expected frequencies.
# ## Alternative Hypothesis: The coin is biased towards tails, and the observed frequencies do not match the expected frequencies.
#
# ## Step 2: Set the significance level
#
# ## The significance level is given as 0.05.
#
# ## Step 3: Determine the expected frequencies
#
# ## If the coin is fair, we would expect a 50-50 split between heads and tails. So, the expected frequency for tails is 0.5 * 100 = 50, and the expected frequency for heads is also 50.
#
# ## Step 4: Calculate the chi-square test statistic
#
# ## The formula to calculate the chi-square test statistic is:
#
# ## χ2 = Σ[(O − E)2 / E]
#
# ## where O is the observed frequency, E is the expected frequency, and Σ is the sum over all categories.
#
# ## Using this formula, we get:
#
# ## χ2 = [(45-50)^2/50] + [(55-50)^2/50] = 1.0
#
# ## Step 5: Determine the degrees of freedom
#
# ## The degrees of freedom for a goodness of fit test is equal to the number of categories minus 1. In this case, there are two categories (heads and tails), so the degrees of freedom is 1.
#
# ## Step 6: Determine the p-value
#
# ## We can use the chi-square distribution with 1 degree of freedom to determine the p-value. Using Python, we get:

# %%
from scipy.stats import chi2

p_value = 1 - chi2.cdf(1.0, 1)

print("p-value:", p_value)
# Out:
# p-value: 0.31731050786291415

# %% [markdown]
# ## Step 7: Interpret the results. Since we fail to reject the null hypothesis, we can conclude that there is not enough evidence to suggest that the coin is biased towards tails.

# %% [markdown]
# # Q9. A study was conducted to determine if there is an association between smoking status (smoker or non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between smoking status and lung cancer diagnosis.

# %%
from scipy.stats import chi2_contingency

observed = [[60, 140], [30, 170]]
chi2, p, dof, expected = chi2_contingency(observed)

print("Chi-square statistic:", chi2)
print("p-value:", p)
# Out:
# Chi-square statistic: 12.057347670250895
# p-value: 0.0005158863863703744

# %% [markdown]
# ## The p-value is very small, indicating strong evidence against the null hypothesis of independence. Therefore, we can conclude that there is a significant association between smoking status and lung cancer diagnosis in the given population.
#
# ## Note that observed is a 2x2 contingency table where the rows represent smoking status and the columns represent lung cancer diagnosis. The expected frequencies are calculated automatically by the chi2_contingency function.

# %% [markdown]
# # Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between chocolate preference and country of origin.

# %%
from scipy.stats import chi2_contingency

# create the contingency table
observed = [[200, 150, 150], [225, 175, 100]]

# conduct chi-square test
chi2, p, dof, expected = chi2_contingency(observed)

# print results
print("Chi-square statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)
# Out:
# Chi-square statistic: 13.393665158371041
# p-value: 0.0012348168997745918
# Degrees of freedom: 2
# Expected frequencies:
#  [[212.5 162.5 125. ]
#  [212.5 162.5 125. ]]

# %%
## The chi-square statistic is 13.39 and the degrees of freedom are 2, which gives a very small p-value of 0.0012348168997745918 This indicates that there is a significant association between chocolate preference and country of origin. Therefore, we reject the null hypothesis of independence and conclude that there is evidence of a relationship between these two variables.

# %% [markdown]
# # Q11. A random sample of 30 people was selected from a population with an unknown mean and standard deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10. Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a significance level of 0.05.
